# %% [markdown]
# In this notebook we make the second analysis of the probabilities outputed with pyUPMASK.

# %%
import numpy as np
import pandas as pd
from astropy.io import ascii
import os
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from cluster_tools import corr_plx, quality_filter, movprop_filter, quality2_filter
import cmasher as cmr

# %%
data = ascii.read("catalogue_2_ngc1027.csv")
data_pyupmask = ascii.read("pyUPMASK/output/ngc1027_pyupmask_3.csv")

# %%
data_pyupmask
# Out:
# <Table length=602>
#     x         y         V     ...   pmDE         Plx         probs_final
#  float64   float64   float64  ... float64      float64         float64
# --------- --------- --------- ... ------- ------------------ -----------
# 41.102165 60.751877  17.73438 ...    1.92           0.644894         0.0
# 40.933933  60.70779 18.265734 ...   1.755           0.997428         0.0
# 41.971382 60.869415 13.546622 ...   2.133 0.9302309999999999      0.0017
# 41.656895 60.831917 18.286827 ...   1.724           0.621899      0.0002
#   41.8517  60.89232 12.826741 ...   1.878           0.941174         0.0
#  41.83841 60.911774 15.608692 ...   2.435           0.698924         0.0
#       ...       ...       ... ...     ...                ...         ...
# 40.610786 62.316376 18.705412 ...   2.443 0.7787569999999999      0.0001
#  40.35215  62.38445 11.635002 ...   1.672 0.9956229999999999         0.0
#  40.33316  62.39931  18.82205 ...   2.411           0.753375         0.0
# 40.929195 62.430004 15.846997 ...   1.891 0.9498169999999999         0.0
# 40.697113  62.46039  17.94505 ...    1.46           0.640252         0.0
# 40.418896 62.564518 13.865103 ...   2.388 0.9893660000000001      0.0002
# 41.803726 62.454464 18.726578 ...   1.584           0.761018         0.0

# %%
len(data)
# Out:
# 602

# %%
data.add_column(data_pyupmask["probs_final"])

# %%
data
# Out:
# <Table length=602>
#  RA_ICRS   DE_ICRS        Source       ...      Plx_corr      probs_final
#  float64   float64        int64        ...      float64         float64
# --------- --------- ------------------ ... ------------------ -----------
# 41.102154 60.751884 464819605794855552 ...           0.644894         0.0
#  40.93392 60.707798 464819915032423680 ...           0.997428         0.0
# 41.971367 60.869427 464833766309733248 ... 0.9302309999999999      0.0017
#  41.65688 60.831924 464835445634360960 ...           0.621899      0.0002
# 41.851685 60.892326 464836652527754368 ...           0.941174         0.0
#  41.83839  60.91178 464837408441994624 ...           0.698924         0.0
#       ...       ...                ... ...                ...         ...
# 40.610764 62.316387 465994056012322816 ... 0.7787569999999999      0.0001
#  40.35213 62.384457 465997118335548672 ... 0.9956229999999999         0.0
#  40.33314 62.399323 465997182748737792 ...           0.753375         0.0
# 40.929176  62.43001 466019207341152256 ... 0.9498169999999999         0.0
# 40.697094 62.460396 466021582466214656 ...           0.640252         0.0
# 40.418877 62.564526 466034982764139008 ... 0.9893660000000001      0.0002
#  41.80371  62.45447 467323507313318784 ...           0.761018         0.0

# %%
RA = data["RAJ2000"]
DE = data["DEJ2000"]
pmra = data["pmRA"]
pmde = data["pmDE"]
plx = data["Plx"]
gmag = data["Gmag"]
bprp = data["BP-RP"]
probs = data["probs_final"]

# %%
#kk,= np.where(plx>0.7)

# %%
len(data[kk])
# Out:
# 532

# %% [markdown]
# ## RA,DEC

# %%
# %matplotlib inline
fig,ax1 = plt.subplots(tight_layout=True)

img = ax1.scatter(RA, DE , c=probs, cmap="gnuplot_r",alpha=0.5,s=30)
ax1.set_ylabel("DEC (deg)",fontsize=17)
ax1.set_xlabel("RA (deg)",fontsize=17)
#ax1.set_title("Position of the clusters in the Galaxy")
cbar = plt.colorbar(img,orientation="vertical",shrink=0.9)
cbar.set_label("Probs",fontsize=15,rotation=270, labelpad=15)
#plt.savefig("dist4_galaxy.png", dpi=150)

# %%
# %matplotlib inline
fig,ax1 = plt.subplots(tight_layout=True)

img = ax1.scatter(pmra, pmde , c=probs, cmap="gnuplot_r",alpha=0.5,s=30)
ax1.set_xlabel("pmRA (mas/yr)",fontsize=17)
ax1.set_ylabel("pmDE (mas/yr)",fontsize=17)
#ax1.set_title("Position of the clusters in the Galaxy")
cbar = plt.colorbar(img,orientation="vertical",shrink=0.9)
cbar.set_label("Probs",fontsize=15,rotation=270, labelpad=15)
#plt.savefig("dist4_galaxy.png", dpi=150)

# %%
fig, ax = plt.subplots()
img=ax.scatter(plx, gmag, c=probs, cmap="gnuplot_r",alpha=0.5,s=30)
ax.set_ylabel("G (mag)",fontsize=17)
ax.set_xlabel("Plx (mas)",fontsize=17)
ax.set_ylim(19,6)
ax.set_xlim(0.,1.5)
cbar = plt.colorbar(img,orientation="vertical",shrink=0.9)
cbar.set_label("Probs",fontsize=15,rotation=270, labelpad=15)

# %%
fig, ax = plt.subplots()
img=ax.scatter(bprp, gmag, c=probs, cmap="gnuplot_r",alpha=0.5,s=30)
ax.set_ylabel("G (mag)",fontsize=17)
ax.set_xlabel(r"G$_{BP}$ - G$_{RP}$ (mag)",fontsize=17)
ax.set_ylim(19,6)
ax.set_xlim(0,2.5)
cbar = plt.colorbar(img,orientation="vertical",shrink=0.9)
cbar.set_label("Probs",fontsize=15,rotation=270, labelpad=15)

# %%
#ascii.write(data, 'ngc1027_pyupmask_final.csv', format='csv', fast_writer=False, overwrite=True)

# %% [markdown]
# Ajusting the isochrones.

# %%
#reading the table of isochrones
iso = ascii.read("isochrones.csv")

# %%
EBV = 0.36
AV = 3.1 * EBV

# Calcular magnitude absoluta corrigida M_d
Md = 10.2

DY = Md + 0.8363*AV
DX = (1.083-0.634)*AV

# %%
kk, = np.where(iso["logAge"] == 8.2)  #binaries
jj, = np.where(iso["logAge"] == 8.1)
ll, = np.where(iso["logAge"] == 8.)  #turn

iso_sel1 = iso[kk]
iso_sel2 = iso[jj]
iso_sel3 = iso[ll]

# %%
fig, ax = plt.subplots()
img=ax.scatter(bprp, gmag, c=probs, cmap="gnuplot_r",alpha=0.5,s=30)
ax.plot((iso_sel1['G_BPmag']-iso_sel1['G_RPmag']) + DX, iso_sel1["Gmag"] + DY, color='r',linestyle='--',linewidth=0.6)
ax.plot((iso_sel2['G_BPmag']-iso_sel2['G_RPmag']) + DX, iso_sel2["Gmag"] + DY, color='r',linewidth=0.9)
ax.plot((iso_sel3['G_BPmag']-iso_sel3['G_RPmag']) + DX, iso_sel3["Gmag"] + DY, color='r',linestyle='--',linewidth=0.6)
ax.set_ylabel("G (mag)",fontsize=17)
ax.set_xlabel(r"G$_{BP}$ - G$_{RP}$ (mag)",fontsize=17)
ax.set_ylim(19,6)
ax.set_xlim(0,2.5)
cbar = plt.colorbar(img,orientation="vertical",shrink=0.9)
cbar.set_label("Probs",fontsize=15,rotation=270, labelpad=15)
ax.text(0.1,16., r"$E(B-V) = 0.36$", bbox={'facecolor':'white','alpha': 0.9, 'pad': 5},fontsize=14)
ax.text(0.1,17.24, r"$(m-M) = 10.2$", bbox={'facecolor':'white','alpha': 0.9, 'pad': 5},fontsize=14)
ax.text(0.1,18.5, r"$log(t/yr) = 8.1$", bbox={'facecolor':'white','alpha': 0.9, 'pad': 5},fontsize=14)
# Out:
# Text(0.1, 18.5, '$log(t/yr) = 8.1$')
